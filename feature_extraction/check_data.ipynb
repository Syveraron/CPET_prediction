# %%
import pandas as pd
import numpy as np
import polars as pl
import time
import matplotlib.pyplot as plt
import neurokit2 as nk
import os

path = '../../../data'

#open the data_labels.csv file
df = pd.read_excel(f'{path}/data_labels.xlsx')

#read in signal freq -> dictionary
file = open(f'{path}/label_freq.txt', 'r')
label_freq = file.read()

label_freq = eval(label_freq)
file.close()

ecg_hz = label_freq['ECG_A']
print(ecg_hz)
# Out:
# 244.140625

# %%
# Assuming df is already defined and loaded
# Add a column to df called ecg_quality
df["ecg_qual"] = np.nan



# Check the percentage of missing data in hr signals and add this to a new column
for index, row in df.iterrows():
    patient_id = row["Patient ID"]

    reformat_path = os.path.join(path, f"hr_values/{patient_id}.npy")

    # Load the npy file
    hr = np.load(reformat_path)

    # Calculate the percentage of the signal that isn't 0 values
    non_zero_percentage = np.sum(hr != 0) / len(hr) * 100
    #print(non_zero_percentage)

    # Add this to the row column value
    df.at[index, "ecg_qual"] = non_zero_percentage

# %%
# Initialize an empty list to store the formatted strings
formatted_list = []

#initialise an empty list to store the patient ID's that need to be removed
to_remove = []

# Loop through the numbers 1 to 198 with R in front to match 
for i in range(1, 199):
    # Add the required prefix based on the number of digits
    if i < 10:
        formatted_list.append(f"R00{i}")
    elif i < 100:
        formatted_list.append(f"R0{i}")
    else:
        formatted_list.append(f"R{i}")

# Loop through the formatted_list and check if each value exists in the 'Patient ID' column
for patient_id in formatted_list:
    if patient_id in df['Patient ID'].values:
        continue
    else:
        print(f"{patient_id} is not present in the DataFrame")
        to_remove.append(patient_id)

print(to_remove)
# Out:
# R095 is not present in the DataFrame
# ['R095']

# %%
# create a new empty column called wear_hrs

df["wear_hrs"] = np.nan

# Loop through the rows of the DataFrame and open the ACC_X file for each patient calculate the lenght in hr using Hz of 25
for index, row in df.iterrows():
    patient_id = row['Patient ID']
    file_name = row['file_name']
    print(f'Processing patient {patient_id}...')

    # Load the ACC_X file
    acc_x = pl.read_parquet(f'{path}/bdf_files/{file_name}/{patient_id}/ACC_X.parquet')
    #ecg = pl.read_parquet(f'{path}/bdf_files/{file_name}/{patient_id}/ECG_A.parquet')

    # convert to numpy array
    acc_x = acc_x.to_numpy()
    #ecg = ecg.to_numpy()


    # Calculate the length of the signal in hours
    length_acc = len(acc_x) / (25*60*60)
    #print(length_acc)

    #length_ecg = len(ecg) / (ecg_hz*60*60)
    #print(length_ecg)

    #if length_acc != length_ecg:
        #print(f'Patient {patient_id} has different signal lengths for ACC_X and ECG_A')
    
    # Add the length to the DataFrame
    df.at[index, 'wear_hrs'] = length_acc

    #print(f'Patient {patient_id} has a signal length of {length} hours')
# Out:
# Processing patient R001...
# Processing patient R002...
# Processing patient R003...
# Processing patient R004...
# Processing patient R005...
# Processing patient R006...
# Processing patient R007...
# Processing patient R008...
# Processing patient R009...
# Processing patient R010...
# Processing patient R011...
# Processing patient R012...
# Processing patient R013...
# Processing patient R014...
# Processing patient R015...
# Processing patient R016...
# Processing patient R017...
# Processing patient R018...
# Processing patient R019...
# Processing patient R020...
# Processing patient R021...
# Processing patient R022...
# Processing patient R023...
# Processing patient R024...
# Processing patient R025...
# Processing patient R026...
# Processing patient R027...
# Processing patient R028...
# Processing patient R029...
# Processing patient R030...
# Processing patient R031...
# Processing patient R032...
# Processing patient R033...
# Processing patient R034...
# Processing patient R035...
# Processing patient R036...
# Processing patient R037...
# Processing patient R038...
# Processing patient R039...
# Processing patient R040...
# Processing patient R041...
# Processing patient R042...
# Processing patient R043...
# Processing patient R044...
# Processing patient R045...
# Processing patient R046...
# Processing patient R047...
# Processing patient R048...
# Processing patient R049...
# Processing patient R050...
# Processing patient R051...
# Processing patient R052...
# Processing patient R053...
# Processing patient R054...
# Processing patient R055...
# Processing patient R056...
# Processing patient R057...
# Processing patient R058...
# Processing patient R059...
# Processing patient R060...
# Processing patient R061...
# Processing patient R062...
# Processing patient R063...
# Processing patient R064...
# Processing patient R065...
# Processing patient R066...
# Processing patient R067...
# Processing patient R068...
# Processing patient R069...
# Processing patient R070...
# Processing patient R071...
# Processing patient R072...
# Processing patient R073...
# Processing patient R074...
# Processing patient R075...
# Processing patient R076...
# Processing patient R077...
# Processing patient R078...
# Processing patient R079...
# Processing patient R080...
# Processing patient R081...
# Processing patient R082...
# Processing patient R083...
# Processing patient R084...
# Processing patient R085...
# Processing patient R086...
# Processing patient R087...
# Processing patient R088...
# Processing patient R089...
# Processing patient R090...
# Processing patient R091...
# Processing patient R092...
# Processing patient R093...
# Processing patient R094...
# Processing patient R096...
# Processing patient R097...
# Processing patient R098...
# Processing patient R099...
# Processing patient R100...
# Processing patient R101...
# Processing patient R102...
# Processing patient R103...
# Processing patient R104...
# Processing patient R105...
# Processing patient R106...
# Processing patient R107...
# Processing patient R108...
# Processing patient R109...
# Processing patient R110...
# Processing patient R111...
# Processing patient R112...
# Processing patient R113...
# Processing patient R114...
# Processing patient R115...
# Processing patient R116...
# Processing patient R117...
# Processing patient R118...
# Processing patient R119...
# Processing patient R120...
# Processing patient R121...
# Processing patient R122...
# Processing patient R123...
# Processing patient R124...
# Processing patient R125...
# Processing patient R126...
# Processing patient R127...
# Processing patient R128...
# Processing patient R129...
# Processing patient R130...
# Processing patient R131...
# Processing patient R132...
# Processing patient R133...
# Processing patient R134...
# Processing patient R135...
# Processing patient R136...
# Processing patient R137...
# Processing patient R138...
# Processing patient R139...
# Processing patient R140...
# Processing patient R141...
# Processing patient R142...
# Processing patient R143...
# Processing patient R144...
# Processing patient R145...
# Processing patient R146...
# Processing patient R147...
# Processing patient R148...
# Processing patient R149...
# Processing patient R150...
# Processing patient R151...
# Processing patient R152...
# Processing patient R153...
# Processing patient R154...
# Processing patient R155...
# Processing patient R156...
# Processing patient R157...
# Processing patient R158...
# Processing patient R159...
# Processing patient R160...
# Processing patient R161...
# Processing patient R162...
# Processing patient R163...
# Processing patient R164...
# Processing patient R165...
# Processing patient R166...
# Processing patient R167...
# Processing patient R168...
# Processing patient R169...
# Processing patient R170...
# Processing patient R171...
# Processing patient R172...
# Processing patient R173...
# Processing patient R174...
# Processing patient R175...
# Processing patient R176...
# Processing patient R177...
# Processing patient R178...
# Processing patient R179...
# Processing patient R180...
# Processing patient R181...
# Processing patient R182...
# Processing patient R183...
# Processing patient R184...
# Processing patient R185...
# Processing patient R186...
# Processing patient R187...
# Processing patient R188...
# Processing patient R189...
# Processing patient R190...
# Processing patient R191...
# Processing patient R192...
# Processing patient R193...
# Processing patient R194...
# Processing patient R195...
# Processing patient R196...
# Processing patient R197...
# Processing patient R198...

# %%
#create a new column called acc_qual and calculate the percentage of missing data in the ACC_X signal (where all axes are < -2)
df['acc_qual'] = np.nan
df['good_wear_hrs'] = np.nan

# Loop through the rows of the DataFrame and open the ACC_X file for each patient calculate the lenght in hr using Hz of 25
for index, row in df.iterrows():
    patient_id = row['Patient ID']
    file_name = row['file_name']
    print(f'Processing patient {patient_id}...')

    # Load the ACC_X file
    acc_x = pl.read_parquet(f'{path}/bdf_files/{file_name}/{patient_id}/ACC_X.parquet')
    acc_y = pl.read_parquet(f'{path}/bdf_files/{file_name}/{patient_id}/ACC_Y.parquet')
    acc_z = pl.read_parquet(f'{path}/bdf_files/{file_name}/{patient_id}/ACC_Z.parquet')

    # convert to numpy array
    acc_x = acc_x.to_numpy()
    acc_y = acc_y.to_numpy()
    acc_z = acc_z.to_numpy()

    #combine the 3 axes and calculate the percentage of the signal where all axes are < -1
    combined = np.stack((acc_x, acc_y, acc_z), axis=1)
    #print(combined)
    #print(combined.shape)

    # Calculate the percentage of the signal where all axes are < -1
    non_zero_percentage = np.sum(np.all(combined < -2, axis=1)) / len(combined) * 100
    good_data = 100 - non_zero_percentage
    print(good_data)

    df.at[index, 'acc_qual'] = good_data

    # Take the value from the wear_hrs column and multiply by the fraction of the signal where all axes are < -1
    wear_time = df.at[index, 'wear_hrs']
    print(wear_time)
    good_wear = wear_time * (good_data/100)
    print(good_wear)
    df.at[index, 'good_wear_hrs'] = good_wear
# Out:
# Processing patient R001...
# 98.69573156130268
# 74.24
# 73.2717111111111
# Processing patient R002...
# 83.08458093619247
# 67.98222222222222
# 56.48274444444444
# Processing patient R003...
# 86.89481278153153
# 94.72
# 82.30676666666666
# Processing patient R004...
# 63.739337744661924
# 79.92888888888889
# 50.94614444444445
# Processing patient R005...
# 86.21051897321429
# 47.78666666666667
# 41.19713333333334
# Processing patient R006...
# 100.0
# 71.96444444444444
# 71.96444444444444
# Processing patient R007...
# 99.9984313484252
# 72.24888888888889
# 72.24775555555556
# Processing patient R008...
# 92.64993866219008
# 68.83555555555556
# 63.7761
# Processing patient R009...
# 99.99826009825327
# 65.13777777777777
# 65.13664444444443
# Processing patient R010...
# 90.54627732240436
# 52.053333333333335
# 47.132355555555556
# Processing patient R011...
# 99.99769315944881
# 72.24888888888889
# 72.24722222222222
# Processing patient R012...
# 100.0
# 43.80444444444444
# 43.80444444444444
# Processing patient R013...
# 99.99834794960475
# 71.96444444444444
# 71.96325555555555
# Processing patient R014...
# 66.15701362781955
# 75.66222222222223
# 50.05586666666667
# Processing patient R015...
# 57.697482638888886
# 71.68
# 41.35755555555556
# Processing patient R016...
# 97.93048406862745
# 72.53333333333333
# 71.03224444444444
# Processing patient R017...
# 99.99845602766798
# 71.96444444444444
# 71.96333333333332
# Processing patient R018...
# 44.79085162213741
# 37.26222222222222
# 16.69006666666667
# Processing patient R019...
# 100.0
# 72.47644444444444
# 72.47644444444444
# Processing patient R020...
# 99.99964628444881
# 72.24888888888889
# 72.24863333333333
# Processing patient R021...
# 99.99668961864407
# 67.1288888888889
# 67.12666666666668
# Processing patient R022...
# 99.93156945850203
# 70.25777777777778
# 70.2097
# Processing patient R023...
# 100.0
# 73.38666666666667
# 73.38666666666667
# Processing patient R024...
# 92.08930173444976
# 59.44888888888889
# 54.746066666666664
# Processing patient R025...
# 18.9645682053942
# 68.55111111111111
# 13.000422222222229
# Processing patient R026...
# 89.05868638833992
# 71.96444444444444
# 64.09058888888889
# Processing patient R027...
# 36.29523111979167
# 68.26666666666667
# 24.777544444444448
# Processing patient R028...
# 99.99991813248504
# 95.00444444444445
# 95.00436666666667
# Processing patient R029...
# 100.0
# 72.81777777777778
# 72.81777777777778
# Processing patient R030...
# 100.0
# 71.96444444444444
# 71.96444444444444
# Processing patient R031...
# 99.99989234744095
# 72.24888888888889
# 72.24881111111111
# Processing patient R032...
# 100.0
# 72.24888888888889
# 72.24888888888889
# Processing patient R033...
# 100.0
# 72.53333333333333
# 72.53333333333333
# Processing patient R034...
# 99.99622026821862
# 70.25777777777778
# 70.25512222222221
# Processing patient R035...
# 99.99834480932203
# 67.1288888888889
# 67.12777777777778
# Processing patient R036...
# 99.99989318847656
# 72.81777777777778
# 72.8177
# Processing patient R037...
# 99.99989192193677
# 71.96444444444444
# 71.96436666666666
# Processing patient R038...
# 99.99384842519684
# 72.24888888888889
# 72.24444444444444
# Processing patient R039...
# 93.66663147522523
# 94.72
# 88.72103333333334
# Processing patient R040...
# 100.0
# 80.49777777777778
# 80.49777777777778
# Processing patient R041...
# 100.0
# 65.99111111111111
# 65.99111111111111
# Processing patient R042...
# 100.0
# 94.72
# 94.72
# Processing patient R043...
# 99.99989192193677
# 71.96444444444444
# 71.96436666666666
# Processing patient R044...
# 99.99479681324111
# 71.96444444444444
# 71.96069999999999
# Processing patient R045...
# 99.99978384387352
# 71.96444444444444
# 71.96428888888887
# Processing patient R046...
# 99.99278846153847
# 55.46666666666667
# 55.46266666666667
# Processing patient R047...
# 100.0
# 72.24888888888889
# 72.24888888888889
# Processing patient R048...
# 100.0
# 72.24888888888889
# 72.24888888888889
# Processing patient R049...
# 97.72770139346966
# 43.12177777777778
# 42.14192222222223
# Processing patient R050...
# 100.0
# 64.56888888888889
# 64.56888888888889
# Processing patient R051...
# 98.20782781862745
# 72.53333333333333
# 71.23341111111111
# Processing patient R052...
# 99.97984693877551
# 69.68888888888888
# 69.67484444444443
# Processing patient R053...
# 99.99976931594489
# 72.24888888888889
# 72.24872222222223
# Processing patient R054...
# 99.99681656003936
# 72.24888888888889
# 72.24658888888888
# Processing patient R055...
# 99.9997846948819
# 72.24888888888889
# 72.24873333333333
# Processing patient R056...
# 100.0
# 76.51555555555555
# 76.51555555555555
# Processing patient R057...
# 99.99992652821317
# 90.73777777777778
# 90.73771111111111
# Processing patient R058...
# 99.99964267151768
# 68.4088888888889
# 68.40864444444445
# Processing patient R059...
# 99.99853698501873
# 75.94666666666667
# 75.94555555555556
# Processing patient R060...
# 95.59344402741515
# 54.471111111111114
# 52.07081111111111
# Processing patient R061...
# 100.0
# 72.53333333333333
# 72.53333333333333
# Processing patient R062...
# 100.0
# 80.49777777777778
# 80.49777777777778
# Processing patient R063...
# 96.67499069940476
# 47.78666666666667
# 46.19775555555556
# Processing patient R064...
# 87.92086450289575
# 73.67111111111112
# 64.77227777777779
# Processing patient R065...
# 99.99987696850394
# 72.24888888888889
# 72.2488
# Processing patient R066...
# 75.56075
# 35.55555555555556
# 26.866044444444444
# Processing patient R067...
# 99.99992629716981
# 90.45333333333333
# 90.45326666666666
# Processing patient R068...
# 99.99821293016194
# 70.25777777777778
# 70.25652222222222
# Processing patient R069...
# 99.99989234744095
# 72.24888888888889
# 72.24881111111111
# Processing patient R070...
# 94.94605152027027
# 31.573333333333334
# 29.977633333333333
# Processing patient R071...
# 99.96727990591398
# 52.906666666666666
# 52.88935555555556
# Processing patient R072...
# 99.99808390106635
# 120.03555555555556
# 120.03325555555556
# Processing patient R073...
# 99.95327653556035
# 65.99111111111111
# 65.96027777777778
# Processing patient R074...
# 100.0
# 75.66222222222223
# 75.66222222222223
# Processing patient R075...
# 100.0
# 69.68888888888888
# 69.68888888888888
# Processing patient R076...
# 99.9984437250996
# 71.39555555555556
# 71.39444444444445
# Processing patient R077...
# 99.99826556467181
# 73.67111111111112
# 73.66983333333333
# Processing patient R078...
# 100.0
# 49.77777777777778
# 49.77777777777778
# Processing patient R079...
# 100.0
# 90.73777777777778
# 90.73777777777778
# Processing patient R080...
# 100.0
# 115.7688888888889
# 115.7688888888889
# Processing patient R081...
# 91.0823016709719
# 78.02312222222223
# 71.06525555555557
# Processing patient R082...
# 99.9996297393365
# 24.00711111111111
# 24.007022222222222
# Processing patient R083...
# 99.99988026819923
# 74.24
# 74.23991111111111
# Processing patient R084...
# 90.37461122630332
# 84.0248888888889
# 75.93716666666667
# Processing patient R085...
# 99.99978125
# 71.11111111111111
# 71.11095555555556
# Processing patient R086...
# 99.99813130403459
# 98.70222222222222
# 98.70037777777777
# Processing patient R087...
# 99.99885110294117
# 96.71111111111111
# 96.71
# Processing patient R088...
# 99.9979222074468
# 53.47555555555556
# 53.47444444444445
# Processing patient R089...
# 99.99846210629921
# 72.24888888888889
# 72.24777777777777
# Processing patient R090...
# 92.93490975935829
# 74.46755555555555
# 69.20635555555555
# Processing patient R091...
# 86.16429227941177
# 67.69777777777777
# 58.33131111111111
# Processing patient R092...
# 99.99698359073359
# 73.67111111111112
# 73.66888888888889
# Processing patient R093...
# 99.99989106075697
# 71.39555555555556
# 71.39547777777777
# Processing patient R094...
# 99.59323601973684
# 10.80888888888889
# 10.764922222222221
# Processing patient R096...
# 85.07214529028435
# 120.03555555555556
# 102.11682222222221
# Processing patient R097...
# 100.0
# 69.68888888888888
# 69.68888888888888
# Processing patient R098...
# 99.99966325431035
# 49.49333333333333
# 49.49316666666667
# Processing patient R099...
# 100.0
# 73.95555555555555
# 73.95555555555555
# Processing patient R100...
# 100.0
# 118.04444444444445
# 118.04444444444445
# Processing patient R101...
# 99.99536350148368
# 95.85777777777778
# 95.85333333333334
# Processing patient R102...
# 100.0
# 71.96444444444444
# 71.96444444444444
# Processing patient R103...
# 100.0
# 73.38666666666667
# 73.38666666666667
# Processing patient R104...
# 100.0
# 72.81777777777778
# 72.81777777777778
# Processing patient R105...
# 82.17556295955882
# 96.71111111111111
# 79.47289999999998
# Processing patient R106...
# 99.9968137254902
# 72.53333333333333
# 72.53102222222222
# Processing patient R107...
# 100.0
# 70.82666666666667
# 70.82666666666667
# Processing patient R108...
# 100.0
# 57.45777777777778
# 57.45777777777778
# Processing patient R109...
# 99.99978885135135
# 42.09777777777778
# 42.09768888888889
# Processing patient R110...
# 100.0
# 73.38666666666667
# 73.38666666666667
# Processing patient R111...
# 95.48131930443549
# 70.54222222222222
# 67.35464444444445
# Processing patient R112...
# 85.20411142676768
# 28.16
# 23.99347777777778
# Processing patient R113...
# 100.0
# 72.53333333333333
# 72.53333333333333
# Processing patient R114...
# 100.0
# 72.53333333333333
# 72.53333333333333
# Processing patient R115...
# 99.99990511133603
# 70.25777777777778
# 70.2577111111111
# Processing patient R116...
# 100.0
# 76.51555555555555
# 76.51555555555555
# Processing patient R117...
# 100.0
# 48.64
# 48.64
# Processing patient R118...
# 94.06460336538461
# 73.95555555555555
# 69.56599999999999
# Processing patient R119...
# 99.99972098214286
# 59.733333333333334
# 59.73316666666667
# Processing patient R120...
# 99.99892695783133
# 118.04444444444445
# 118.04317777777779
# Processing patient R121...
# 96.78208544075144
# 49.208888888888886
# 47.625388888888885
# Processing patient R122...
# 99.99989106075697
# 71.39555555555556
# 71.39547777777777
# Processing patient R123...
# 100.0
# 73.10222222222222
# 73.10222222222222
# Processing patient R124...
# 99.59538612565446
# 54.32888888888889
# 54.10906666666668
# Processing patient R125...
# 100.0
# 72.53333333333333
# 72.53333333333333
# Processing patient R126...
# 99.99977859311741
# 70.25777777777778
# 70.25762222222222
# Processing patient R127...
# 88.55943080357143
# 55.75111111111111
# 49.37286666666666
# Processing patient R128...
# 100.0
# 73.10222222222222
# 73.10222222222222
# Processing patient R129...
# 99.99581801470588
# 72.53333333333333
# 72.5303
# Processing patient R130...
# 99.99964628444881
# 72.24888888888889
# 72.24863333333333
# Processing patient R131...
# 99.99978298611111
# 71.68
# 71.67984444444446
# Processing patient R132...
# 99.99989276960784
# 72.53333333333333
# 72.53325555555554
# Processing patient R133...
# 99.99987086776859
# 68.83555555555556
# 68.83546666666666
# Processing patient R134...
# 95.45444730201864
# 91.5911111111111
# 87.42778888888888
# Processing patient R135...
# 99.99953245656371
# 73.67111111111112
# 73.67076666666668
# Processing patient R136...
# 99.9988234186747
# 70.82666666666667
# 70.82583333333334
# Processing patient R137...
# 99.99610639158576
# 87.89333333333333
# 87.8899111111111
# Processing patient R138...
# 99.99989401647287
# 73.38666666666667
# 73.3865888888889
# Processing patient R139...
# 100.0
# 72.81777777777778
# 72.81777777777778
# Processing patient R140...
# 99.99601403061224
# 55.75111111111111
# 55.748888888888885
# Processing patient R141...
# 100.0
# 72.24888888888889
# 72.24888888888889
# Processing patient R142...
# 100.0
# 75.66222222222223
# 75.66222222222223
# Processing patient R143...
# 98.44187830438067
# 94.1511111111111
# 92.68412222222223
# Processing patient R144...
# 74.38533579192547
# 91.5911111111111
# 68.13035555555555
# Processing patient R145...
# 97.79293799212599
# 72.24888888888889
# 70.65431111111111
# Processing patient R146...
# 74.40328235424028
# 80.49777777777778
# 59.89298888888889
# Processing patient R147...
# 97.86150981104652
# 73.38666666666667
# 71.81730000000002
# Processing patient R148...
# 74.70186941964286
# 87.60888888888888
# 65.44547777777778
# Processing patient R149...
# 97.82481152723736
# 73.10222222222222
# 71.51211111111111
# Processing patient R150...
# 100.0
# 70.82666666666667
# 70.82666666666667
# Processing patient R151...
# 100.0
# 73.38666666666667
# 73.38666666666667
# Processing patient R152...
# 100.0
# 70.25777777777778
# 70.25777777777778
# Processing patient R153...
# 99.99841678503788
# 75.09333333333333
# 75.09214444444444
# Processing patient R154...
# 99.99976373487904
# 70.54222222222222
# 70.54205555555556
# Processing patient R155...
# 99.853515625
# 80.78222222222222
# 80.66388888888888
# Processing patient R156...
# 100.0
# 73.38666666666667
# 73.38666666666667
# Processing patient R157...
# 94.53922911729858
# 120.03555555555556
# 113.48068888888889
# Processing patient R158...
# 100.0
# 73.67111111111112
# 73.67111111111112
# Processing patient R159...
# 94.44956683168317
# 28.72888888888889
# 27.134311111111113
# Processing patient R160...
# 99.99516444052419
# 70.54222222222222
# 70.5388111111111
# Processing patient R161...
# 100.0
# 73.10222222222222
# 73.10222222222222
# Processing patient R162...
# 43.45062584005376
# 52.906666666666666
# 22.988277777777775
# Processing patient R163...
# 92.83006237399194
# 70.54222222222222
# 65.48438888888889
# Processing patient R164...
# 100.0
# 72.24888888888889
# 72.24888888888889
# Processing patient R165...
# 99.99981219951923
# 88.74666666666667
# 88.7465
# Processing patient R166...
# 99.99747983870968
# 88.17777777777778
# 88.17555555555556
# Processing patient R167...
# 100.0
# 77.08444444444444
# 77.08444444444444
# Processing patient R168...
# 67.46216354927007
# 116.90666666666667
# 78.86776666666667
# Processing patient R169...
# 99.99989234744095
# 72.24888888888889
# 72.24881111111111
# Processing patient R170...
# 100.0
# 73.67111111111112
# 73.67111111111112
# Processing patient R171...
# 100.0
# 70.82666666666667
# 70.82666666666667
# Processing patient R172...
# 100.0
# 58.595555555555556
# 58.595555555555556
# Processing patient R173...
# 100.0
# 71.68
# 71.68
# Processing patient R174...
# 97.71281887755102
# 69.68888888888888
# 68.09497777777777
# Processing patient R175...
# 87.16191555343511
# 37.26222222222222
# 32.47846666666666
# Processing patient R176...
# 100.0
# 73.38666666666667
# 73.38666666666667
# Processing patient R177...
# 94.75198245571814
# 73.87022222222222
# 69.9935
# Processing patient R178...
# 100.0
# 71.96444444444444
# 71.96444444444444
# Processing patient R179...
# 97.699951171875
# 68.26666666666667
# 66.6965
# Processing patient R180...
# 97.8015931372549
# 72.53333333333333
# 70.93875555555555
# Processing patient R181...
# 100.0
# 73.10222222222222
# 73.10222222222222
# Processing patient R182...
# 100.0
# 43.23555555555556
# 43.23555555555556
# Processing patient R183...
# 23.5159952606635
# 120.03555555555556
# 28.22755555555555
# Processing patient R184...
# 99.99967073754789
# 74.24
# 74.23975555555555
# Processing patient R185...
# 100.0
# 68.83555555555556
# 68.83555555555556
# Processing patient R186...
# 99.99723939929329
# 80.49777777777778
# 80.49555555555557
# Processing patient R187...
# 99.9084980867347
# 69.68888888888888
# 69.62512222222222
# Processing patient R188...
# 99.962047057393
# 73.10222222222222
# 73.07447777777777
# Processing patient R189...
# 100.0
# 73.38666666666667
# 73.38666666666667
# Processing patient R190...
# 99.99976931594489
# 72.24888888888889
# 72.24872222222223
# Processing patient R191...
# 98.19604099678456
# 88.46222222222222
# 86.8664
# Processing patient R192...
# 99.99396634615384
# 92.44444444444444
# 92.43886666666666
# Processing patient R193...
# 100.0
# 73.95555555555555
# 73.95555555555555
# Processing patient R194...
# 99.97104511186771
# 73.10222222222222
# 73.08105555555557
# Processing patient R195...
# 100.0
# 72.24888888888889
# 72.24888888888889
# Processing patient R196...
# 100.0
# 73.38666666666667
# 73.38666666666667
# Processing patient R197...
# 100.0
# 72.81777777777778
# 72.81777777777778
# Processing patient R198...
# 100.0
# 71.68
# 71.68

# %%
to_remove = []

for index, row in df.iterrows():
    if row['good_wear_hrs'] < 24:
        print(f"Patient ID: {row['Patient ID']}, Wear time: {row['Wear time']}")
        to_remove.append(row['Patient ID'])

print(to_remove)
# Out:
# Patient ID: R018, Wear time: 37.26222222222222
# Patient ID: R025, Wear time: 68.55111111111111
# Patient ID: R094, Wear time: 10.80888888888889
# Patient ID: R112, Wear time: 22.1600005
# Patient ID: R162, Wear time: 52.90666666666667
# ['R018', 'R025', 'R094', 'R112', 'R162']

# %%
counter = 0

for index, row in df.iterrows():
    # Calculate the remaining hours
    patient_id = row["Patient ID"]
    print(patient_id)

    reformat_path = os.path.join(path, f"hr_values/{patient_id}.npy")

    # Load the npy file
    hr = np.load(reformat_path)

    #extract the first 24hrs of the hr signal only (each hr value is 10s of time)
    hr_data = hr[:6*60*24]

    # Resample HR data to 1-minute intervals by taking the median of each 6 values, excluding zeros. If all 0s then HR is 0
    hr_resampled = []
    for i in range(0, len(hr_data), 6):
        chunk = hr_data[i:i+6]
        non_zero_chunk = chunk[chunk != 0]
        median = np.mean(non_zero_chunk) if len(non_zero_chunk) > 0 else 0
        hr_resampled.append(median)

    #count how many 0s in hr_resampled, if less 18hrs of hr than add to to_remove list if not already there
    zero_count = hr_resampled.count(0)
    print(zero_count)
    if zero_count > 60*6:
        if patient_id not in to_remove:
            to_remove.append(patient_id)
            counter += 1

print(f"Number of patients to remove: {counter}")
print(to_remove)
# Out:
# R001
# 53
# R002
# 618
# R003
# 654
# R004
# 917
# R005
# 415
# R006
# 2
# R007
# 40
# R008
# 12
# R009
# 714
# R010
# 10
# R011
# 1
# R012
# 87
# R013
# 48
# R014
# 1263
# R015
# 670
# R016
# 112
# R017
# 6
# R018
# 527
# R019
# 60
# R020
# 42
# R021
# 24
# R022
# 23
# R023
# 55
# R024
# 49
# R025
# 863
# R026
# 138
# R027
# 597
# R028
# 1
# R029
# 47
# R030
# 169
# R031
# 21
# R032
# 185
# R033
# 184
# R034
# 46
# R035
# 121
# R036
# 84
# R037
# 132
# R038
# 6
# R039
# 32
# R040
# 163
# R041
# 8
# R042
# 425
# R043
# 71
# R044
# 7
# R045
# 77
# R046
# 78
# R047
# 819
# R048
# 4
# R049
# 232
# R050
# 10
# R051
# 4
# R052
# 69
# R053
# 2
# R054
# 20
# R055
# 1
# R056
# 112
# R057
# 531
# R058
# 265
# R059
# 96
# R060
# 11
# R061
# 405
# R062
# 365
# R063
# 39
# R064
# 39
# R065
# 1
# R066
# 447
# R067
# 11
# R068
# 9
# R069
# 87
# R070
# 196
# R071
# 10
# R072
# 1
# R073
# 44
# R074
# 39
# R075
# 31
# R076
# 5
# R077
# 481
# R078
# 128
# R079
# 263
# R080
# 60
# R081
# 494
# R082
# 7
# R083
# 47
# R084
# 46
# R085
# 11
# R086
# 64
# R087
# 59
# R088
# 201
# R089
# 3
# R090
# 0
# R091
# 43
# R092
# 7
# R093
# 25
# R094
# 88
# R096
# 65
# R097
# 118
# R098
# 880
# R099
# 10
# R100
# 135
# R101
# 10
# R102
# 41
# R103
# 60
# R104
# 217
# R105
# 2
# R106
# 3
# R107
# 8
# R108
# 317
# R109
# 260
# R110
# 16
# R111
# 6
# R112
# 157
# R113
# 91
# R114
# 8
# R115
# 28
# R116
# 4
# R117
# 23
# R118
# 53
# R119
# 211
# R120
# 963
# R121
# 3
# R122
# 36
# R123
# 10
# R124
# 102
# R125
# 11
# R126
# 90
# R127
# 30
# R128
# 5
# R129
# 468
# R130
# 477
# R131
# 84
# R132
# 35
# R133
# 18
# R134
# 32
# R135
# 393
# R136
# 2
# R137
# 31
# R138
# 2
# R139
# 1
# R140
# 26
# R141
# 96
# R142
# 44
# R143
# 90
# R144
# 297
# R145
# 3
# R146
# 420
# R147
# 4
# R148
# 580
# R149
# 169
# R150
# 23
# R151
# 5
# R152
# 66
# R153
# 52
# R154
# 20
# R155
# 5
# R156
# 8
# R157
# 180
# R158
# 140
# R159
# 9
# R160
# 172
# R161
# 154
# R162
# 1366
# R163
# 14
# R164
# 398
# R165
# 0
# R166
# 97
# R167
# 26
# R168
# 191
# R169
# 3
# R170
# 30
# R171
# 22
# R172
# 117
# R173
# 1
# R174
# 195
# R175
# 14
# R176
# 545
# R177
# 7
# R178
# 56
# R179
# 422
# R180
# 567
# R181
# 585
# R182
# 3
# R183
# 266
# R184
# 8
# R185
# 40
# R186
# 96
# R187
# 8
# R188
# 255
# R189
# 2
# R190
# 31
# R191
# 4
# R192
# 99
# R193
# 266
# R194
# 211
# R195
# 1
# R196
# 2
# R197
# 88
# R198
# 317
# Number of patients to remove: 28
# ['R018', 'R025', 'R094', 'R112', 'R162', 'R002', 'R003', 'R004', 'R005', 'R009', 'R014', 'R015', 'R027', 'R042', 'R047', 'R057', 'R061', 'R062', 'R066', 'R077', 'R081', 'R098', 'R120', 'R129', 'R130', 'R135', 'R146', 'R148', 'R164', 'R176', 'R179', 'R180', 'R181']

# %%
print(len(to_remove))
# Out:
# 33

# %%
new = ['R026', 'R066', 'R114', 'R174', 'R186']

#check if any patients in the new list are already in the to_remove list
for patient in new:
    if patient in to_remove:
        print(f"{patient} is already in the to_remove list")
    else:
        print(f"{patient} is not in the to_remove list")
        #add the patient to the to_remove list
        to_remove.append(patient)
# Out:
# R026 is not in the to_remove list
# R066 is already in the to_remove list
# R114 is not in the to_remove list
# R174 is not in the to_remove list
# R186 is not in the to_remove list

# %%
#save to_remove list to a text file titled 'patients_to_remove2.txt'
file = open(f'{path}/patients_to_remove3.txt', 'w')
file.write(str(to_remove))
file.close()

# %%
for index, row in df.iterrows():
    # Calculate the remaining hours
    patient_id = row["Patient ID"]

    reformat_path = os.path.join(path, f"hr_values/{patient_id}.npy")

    # Load the npy file
    hr = np.load(reformat_path)

    # Calculate the percentage of the signal that isn't 0 values
    non_zero_percentage = np.sum(hr != 0)

    #each non_zero value is 10s, calculate the total time in hours of non-zero values
    total_time = non_zero_percentage / 6
    total_time_hrs = total_time / 60


    print(f"Patient ID: {patient_id}, Remaining hours: {total_time_hrs}")

    
    
    # Check if the remaining hrs is less than 24
    if total_time_hrs < 24:
        print(f"Patient ID: {row['Patient ID']}, Remaining hrs: {total_time_hrs}")
        #if value is not already in to_remove list, add it
        if row['Patient ID'] not in to_remove:
            to_remove.append(row['Patient ID'])

print(to_remove)
print(len(to_remove))
# Out:
# Patient ID: R001, Remaining hours: 56.06111111111111
# Patient ID: R002, Remaining hours: 50.425
# Patient ID: R003, Remaining hours: 81.25277777777778
# Patient ID: R004, Remaining hours: 48.59166666666667
# Patient ID: R005, Remaining hours: 26.105555555555554
# Patient ID: R006, Remaining hours: 70.63611111111112
# Patient ID: R007, Remaining hours: 65.34166666666667
# Patient ID: R008, Remaining hours: 57.68333333333333
# Patient ID: R009, Remaining hours: 15.56388888888889
# Patient ID: R009, Remaining hrs: 15.56388888888889
# Patient ID: R010, Remaining hours: 40.9
# Patient ID: R011, Remaining hours: 53.66388888888889
# Patient ID: R012, Remaining hours: 36.083333333333336
# Patient ID: R013, Remaining hours: 56.31388888888889
# Patient ID: R014, Remaining hours: 33.577777777777776
# Patient ID: R015, Remaining hours: 31.194444444444446
# Patient ID: R016, Remaining hours: 65.23055555555555
# Patient ID: R017, Remaining hours: 47.25277777777777
# Patient ID: R018, Remaining hours: 14.052777777777777
# Patient ID: R018, Remaining hrs: 14.052777777777777
# Patient ID: R019, Remaining hours: 53.31111111111111
# Patient ID: R020, Remaining hours: 44.14444444444444
# Patient ID: R021, Remaining hours: 61.56944444444444
# Patient ID: R022, Remaining hours: 64.225
# Patient ID: R023, Remaining hours: 62.43611111111111
# Patient ID: R024, Remaining hours: 47.01944444444444
# Patient ID: R025, Remaining hours: 6.688888888888888
# Patient ID: R025, Remaining hrs: 6.688888888888888
# Patient ID: R026, Remaining hours: 51.102777777777774
# Patient ID: R027, Remaining hours: 24.05
# Patient ID: R028, Remaining hours: 69.41944444444445
# Patient ID: R029, Remaining hours: 49.511111111111106
# Patient ID: R030, Remaining hours: 49.416666666666664
# Patient ID: R031, Remaining hours: 68.0111111111111
# Patient ID: R032, Remaining hours: 57.41111111111111
# Patient ID: R033, Remaining hours: 49.4
# Patient ID: R034, Remaining hours: 47.025
# Patient ID: R035, Remaining hours: 51.863888888888894
# Patient ID: R036, Remaining hours: 38.69444444444444
# Patient ID: R037, Remaining hours: 61.358333333333334
# Patient ID: R038, Remaining hours: 66.42222222222223
# Patient ID: R039, Remaining hours: 83.45
# Patient ID: R040, Remaining hours: 48.13888888888889
# Patient ID: R041, Remaining hours: 60.13888888888889
# Patient ID: R042, Remaining hours: 53.30277777777778
# Patient ID: R043, Remaining hours: 59.47222222222222
# Patient ID: R044, Remaining hours: 59.577777777777776
# Patient ID: R045, Remaining hours: 56.977777777777774
# Patient ID: R046, Remaining hours: 39.827777777777776
# Patient ID: R047, Remaining hours: 20.913888888888888
# Patient ID: R047, Remaining hrs: 20.913888888888888
# Patient ID: R048, Remaining hours: 69.55277777777778
# Patient ID: R049, Remaining hours: 29.719444444444445
# Patient ID: R050, Remaining hours: 63.02777777777778
# Patient ID: R051, Remaining hours: 62.85
# Patient ID: R052, Remaining hours: 35.81944444444444
# Patient ID: R053, Remaining hours: 66.4
# Patient ID: R054, Remaining hours: 68.43055555555556
# Patient ID: R055, Remaining hours: 70.82222222222222
# Patient ID: R056, Remaining hours: 55.80555555555556
# Patient ID: R057, Remaining hours: 49.1
# Patient ID: R058, Remaining hours: 48.22222222222222
# Patient ID: R059, Remaining hours: 63.71944444444444
# Patient ID: R060, Remaining hours: 50.56111111111111
# Patient ID: R061, Remaining hours: 46.958333333333336
# Patient ID: R062, Remaining hours: 46.044444444444444
# Patient ID: R063, Remaining hours: 31.98611111111111
# Patient ID: R064, Remaining hours: 62.272222222222226
# Patient ID: R065, Remaining hours: 61.16111111111111
# Patient ID: R066, Remaining hours: 18.50277777777778
# Patient ID: R066, Remaining hrs: 18.50277777777778
# Patient ID: R067, Remaining hours: 83.125
# Patient ID: R068, Remaining hours: 56.147222222222226
# Patient ID: R069, Remaining hours: 32.577777777777776
# Patient ID: R070, Remaining hours: 19.23611111111111
# Patient ID: R070, Remaining hrs: 19.23611111111111
# Patient ID: R071, Remaining hours: 36.3
# Patient ID: R072, Remaining hours: 118.73333333333333
# Patient ID: R073, Remaining hours: 61.66111111111111
# Patient ID: R074, Remaining hours: 56.63888888888889
# Patient ID: R075, Remaining hours: 64.1861111111111
# Patient ID: R076, Remaining hours: 66.83055555555556
# Patient ID: R077, Remaining hours: 49.73611111111111
# Patient ID: R078, Remaining hours: 23.33888888888889
# Patient ID: R078, Remaining hrs: 23.33888888888889
# Patient ID: R079, Remaining hours: 79.41666666666667
# Patient ID: R080, Remaining hours: 100.06111111111112
# Patient ID: R081, Remaining hours: 44.47222222222222
# Patient ID: R082, Remaining hours: 37.125
# Patient ID: R083, Remaining hours: 68.72222222222221
# Patient ID: R084, Remaining hours: 69.47222222222221
# Patient ID: R085, Remaining hours: 65.05277777777778
# Patient ID: R086, Remaining hours: 56.46388888888889
# Patient ID: R087, Remaining hours: 94.175
# Patient ID: R088, Remaining hours: 34.41388888888889
# Patient ID: R089, Remaining hours: 69.03333333333333
# Patient ID: R090, Remaining hours: 57.09722222222222
# Patient ID: R091, Remaining hours: 54.75555555555556
# Patient ID: R092, Remaining hours: 58.455555555555556
# Patient ID: R093, Remaining hours: 47.90833333333333
# Patient ID: R094, Remaining hours: 9.041666666666666
# Patient ID: R094, Remaining hrs: 9.041666666666666
# Patient ID: R096, Remaining hours: 74.86944444444445
# Patient ID: R097, Remaining hours: 56.87222222222223
# Patient ID: R098, Remaining hours: 18.658333333333335
# Patient ID: R098, Remaining hrs: 18.658333333333335
# Patient ID: R099, Remaining hours: 68.90277777777779
# Patient ID: R100, Remaining hours: 95.34166666666667
# Patient ID: R101, Remaining hours: 79.10833333333333
# Patient ID: R102, Remaining hours: 66.36666666666666
# Patient ID: R103, Remaining hours: 71.62777777777778
# Patient ID: R104, Remaining hours: 56.94444444444444
# Patient ID: R105, Remaining hours: 70.975
# Patient ID: R106, Remaining hours: 72.13055555555555
# Patient ID: R107, Remaining hours: 64.5611111111111
# Patient ID: R108, Remaining hours: 43.88333333333333
# Patient ID: R109, Remaining hours: 34.175
# Patient ID: R110, Remaining hours: 70.36944444444445
# Patient ID: R111, Remaining hours: 52.705555555555556
# Patient ID: R112, Remaining hours: 19.741666666666667
# Patient ID: R112, Remaining hrs: 19.741666666666667
# Patient ID: R113, Remaining hours: 63.64444444444444
# Patient ID: R114, Remaining hours: 62.825
# Patient ID: R115, Remaining hours: 62.82222222222222
# Patient ID: R116, Remaining hours: 69.24722222222222
# Patient ID: R117, Remaining hours: 24.63888888888889
# Patient ID: R118, Remaining hours: 63.36944444444444
# Patient ID: R119, Remaining hours: 29.866666666666667
# Patient ID: R120, Remaining hours: 63.61111111111111
# Patient ID: R121, Remaining hours: 46.83611111111111
# Patient ID: R122, Remaining hours: 67.60277777777777
# Patient ID: R123, Remaining hours: 66.54722222222223
# Patient ID: R124, Remaining hours: 34.925
# Patient ID: R125, Remaining hours: 67.6888888888889
# Patient ID: R126, Remaining hours: 55.06666666666667
# Patient ID: R127, Remaining hours: 46.72222222222222
# Patient ID: R128, Remaining hours: 71.66944444444445
# Patient ID: R129, Remaining hours: 39.25277777777777
# Patient ID: R130, Remaining hours: 50.3
# Patient ID: R131, Remaining hours: 59.083333333333336
# Patient ID: R132, Remaining hours: 70.91944444444445
# Patient ID: R133, Remaining hours: 63.983333333333334
# Patient ID: R134, Remaining hours: 72.84166666666667
# Patient ID: R135, Remaining hours: 22.025
# Patient ID: R135, Remaining hrs: 22.025
# Patient ID: R136, Remaining hours: 66.625
# Patient ID: R137, Remaining hours: 83.825
# Patient ID: R138, Remaining hours: 72.92777777777778
# Patient ID: R139, Remaining hours: 72.38888888888889
# Patient ID: R140, Remaining hours: 52.31111111111111
# Patient ID: R141, Remaining hours: 56.330555555555556
# Patient ID: R142, Remaining hours: 68.2
# Patient ID: R143, Remaining hours: 83.36666666666666
# Patient ID: R144, Remaining hours: 63.28333333333333
# Patient ID: R145, Remaining hours: 69.30277777777778
# Patient ID: R146, Remaining hours: 54.43055555555556
# Patient ID: R147, Remaining hours: 66.92777777777778
# Patient ID: R148, Remaining hours: 23.711111111111112
# Patient ID: R148, Remaining hrs: 23.711111111111112
# Patient ID: R149, Remaining hours: 50.50833333333333
# Patient ID: R150, Remaining hours: 59.06666666666667
# Patient ID: R151, Remaining hours: 67.07777777777777
# Patient ID: R152, Remaining hours: 55.68055555555556
# Patient ID: R153, Remaining hours: 68.82222222222222
# Patient ID: R154, Remaining hours: 45.06111111111111
# Patient ID: R155, Remaining hours: 77.80555555555556
# Patient ID: R156, Remaining hours: 68.94166666666666
# Patient ID: R157, Remaining hours: 51.36666666666667
# Patient ID: R158, Remaining hours: 59.05277777777778
# Patient ID: R159, Remaining hours: 26.55277777777778
# Patient ID: R160, Remaining hours: 50.363888888888894
# Patient ID: R161, Remaining hours: 52.81944444444444
# Patient ID: R162, Remaining hours: 20.069444444444446
# Patient ID: R162, Remaining hrs: 20.069444444444446
# Patient ID: R163, Remaining hours: 62.71388888888889
# Patient ID: R164, Remaining hours: 41.458333333333336
# Patient ID: R165, Remaining hours: 67.21666666666667
# Patient ID: R166, Remaining hours: 63.46944444444444
# Patient ID: R167, Remaining hours: 68.16388888888889
# Patient ID: R168, Remaining hours: 50.922222222222224
# Patient ID: R169, Remaining hours: 62.73055555555556
# Patient ID: R170, Remaining hours: 69.45277777777778
# Patient ID: R171, Remaining hours: 61.86666666666667
# Patient ID: R172, Remaining hours: 48.06666666666667
# Patient ID: R173, Remaining hours: 69.26944444444445
# Patient ID: R174, Remaining hours: 47.08888888888889
# Patient ID: R175, Remaining hours: 32.03055555555555
# Patient ID: R176, Remaining hours: 42.825
# Patient ID: R177, Remaining hours: 69.24722222222222
# Patient ID: R178, Remaining hours: 58.36111111111111
# Patient ID: R179, Remaining hours: 30.163888888888888
# Patient ID: R180, Remaining hours: 30.625
# Patient ID: R181, Remaining hours: 34.71388888888889
# Patient ID: R182, Remaining hours: 40.169444444444444
# Patient ID: R183, Remaining hours: 19.216666666666665
# Patient ID: R183, Remaining hrs: 19.216666666666665
# Patient ID: R184, Remaining hours: 66.35833333333333
# Patient ID: R185, Remaining hours: 62.169444444444444
# Patient ID: R186, Remaining hours: 61.65
# Patient ID: R187, Remaining hours: 65.79722222222223
# Patient ID: R188, Remaining hours: 53.32222222222222
# Patient ID: R189, Remaining hours: 68.25
# Patient ID: R190, Remaining hours: 59.30555555555556
# Patient ID: R191, Remaining hours: 73.71388888888889
# Patient ID: R192, Remaining hours: 70.00555555555555
# Patient ID: R193, Remaining hours: 46.397222222222226
# Patient ID: R194, Remaining hours: 30.063888888888886
# Patient ID: R195, Remaining hours: 69.08888888888889
# Patient ID: R196, Remaining hours: 69.25833333333334
# Patient ID: R197, Remaining hours: 54.15833333333333
# Patient ID: R198, Remaining hours: 64.79166666666667
# ['R018', 'R025', 'R094', 'R112', 'R162', 'R002', 'R003', 'R004', 'R009', 'R014', 'R015', 'R027', 'R047', 'R057', 'R077', 'R081', 'R098', 'R120', 'R148', 'R176', 'R180', 'R181', 'R026', 'R066', 'R114', 'R174', 'R186', 'R070', 'R078', 'R135', 'R183']
# 31

# %%
#open a text file and write the patient ID's to be removed and save this under the data folder
file = open(f'{path}/patients_to_remove.txt', 'w')
file.write(str(to_remove))
file.close()

# %%
print(df.columns)
#remove the columns 'Wear time', 'missing ACC (% of total signal)', 'missing ECG overall (% of total signal)', 'Missing ECG from electrode (% of total signal)'
df = df.drop(columns=['Wear time', 'missing ACC (% of total signal)', 'missing ECG overall (% of total signal)', 'Missing ECG from electrode (% of total signal)'])

#save to a csv file
df.to_csv(f'{path}/sensor_data.csv', index=False)
# Out:
# Index(['Patient ID', 'Biosensor ID', 'file_name', 'Start', 'Wear time',
#        'missing ACC (% of total signal)',
#        'missing ECG overall (% of total signal)',
#        'Missing ECG from electrode (% of total signal)', 'ecg_qual',
#        'wear_hrs', 'acc_qual', 'good_wear_hrs'],
#       dtype='object')
